# %%
import legaltechDataProcess as ltp
import jieba.analyse
import jieba 
import pandas as pd
import numpy as np
import nltk
from collections import Counter
import re  
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import random

# %% [markdown]
# # 資料處理區

# %%
x=pd.read_pickle("/Users/benbilly3/Desktop/Legaltech/MoreData/result.pickle")
# x['jd_money']=x['jd_money'].replace('',0).astype(int)
# x['solatium_request']=x['solatium_request'].replace('',0).astype(int)
t1=x['jd_money'].values.tolist()
t2=x['solatium_request'].values.tolist()
#法院判決金額概估，若法院金額大於請求金額，推測請求成功，打8折當保險值。
#若法院金額小於請求金額，推測請求失敗，以法院實判金額打7折當保險值。
x['jd_solatium_predict']=[b*0.8 if a>=b else a*0.7 for a,b in zip(t1,t2)]
# x.to_pickle("/Users/benbilly3/Desktop/Legaltech/MoreData/result.pickle")
x
# Out:
#            court                       date                       historyHash  \
# 1970    福建連江地方法院  2016-08-17T00:00:00+08:00  c74d75deba75b2c8cb3207d1910235d1
# 2012    福建金門地方法院  2012-02-15T00:00:00+08:00  2cb882cc11e9df8dc6d38f452f5924a3
# 2040    福建金門地方法院  2008-12-22T00:00:00+08:00
# 2041    福建金門地方法院  2009-05-21T00:00:00+08:00
# 2049    福建金門地方法院  2010-02-04T00:00:00+08:00  09f5f13c3a5b4352bfe848bc6cf41c39
# 2169    福建金門地方法院  2012-11-23T00:00:00+08:00
# 2170    福建金門地方法院  2014-06-10T00:00:00+08:00
# 2174    福建金門地方法院  2012-08-30T00:00:00+08:00
# 2175    福建金門地方法院  2013-03-22T00:00:00+08:00  231a60a312050c0710acd1b53cc42d53
# 2191    福建金門地方法院  2013-09-26T00:00:00+08:00  b8c82b71d6e2cb2ae0453c9b914880bc
# 2192    福建金門地方法院  2014-01-14T00:00:00+08:00  b80f8902e1b986037f61f88b9301da3e
# 2193    福建金門地方法院  2013-10-21T00:00:00+08:00  83a3e539588d1c662901d6d9bf526392
# 2202    福建金門地方法院  2014-10-02T00:00:00+08:00
# 2217    福建金門地方法院  2017-08-31T00:00:00+08:00
# 2228    福建金門地方法院  2016-06-13T00:00:00+08:00
# 2234    福建金門地方法院  2016-12-29T00:00:00+08:00
# 2250    福建金門地方法院  2018-02-13T00:00:00+08:00
# 2263    福建金門地方法院  2018-04-25T00:00:00+08:00
# 2264    福建金門地方法院  2017-09-26T00:00:00+08:00  68b8c89ccd6f162edc67764acbb869dd
# 2268    福建金門地方法院  2018-03-08T00:00:00+08:00
# 2272    福建金門地方法院  2018-06-26T00:00:00+08:00
# 2273    福建金門地方法院  2018-07-05T00:00:00+08:00
# 2275    福建金門地方法院  2018-03-08T00:00:00+08:00
# 2289    福建金門地方法院  2018-05-07T00:00:00+08:00
# 2294    福建金門地方法院  2018-09-05T00:00:00+08:00
# 2304    福建金門地方法院  2018-06-13T00:00:00+08:00  5bb6b297fe71dbaf6090a12193b25dcf
# 2306    福建金門地方法院  2008-03-06T00:00:00+08:00
# 2311    福建金門地方法院  2008-08-22T00:00:00+08:00
# 2315    福建金門地方法院  2008-06-30T00:00:00+08:00
# 2323    福建金門地方法院  2009-12-18T00:00:00+08:00  ed97be01c32bedbb534f66e56ea363ef
# 336056  並聲明：(一)原告之訴駁回。(二)如受不利判決，願供擔保，請准宣告免為假執行。四、按因故意或...
# 336297  一、按訴狀送達後，原告不得將原訴變更或追加他訴，但擴張或減縮應受判決事項之聲明、不甚礙被告之...
# 336303  三、兩造不爭執之事實(一)、被告張西良為被告指南客運之受僱人，原告於被告張西良執行職務駕駛系...
# 336394  (二)經查：1.原告主張之事實，固據提出北市○○○○○道路交通事故初步分析研判表、事故現場相...
# 336425  四、而被告既以前詞置辯，是本件主要爭點應為：（一）前述外洩而經原告吸入之氣體，是否足以造成原...
# 336438  三、得心證之理由：(一)按因故意或過失，不法侵害他人之權利者，負損害賠償責任；不法侵害他人之...
# 336475  (一)按非公務機關保有個人資料檔案者，應採行適當之安全措施，防止個人資料被竊取、竄改、毀損、...
#
#                                                     party    reason  \
# 1970    [{'group': ['plaintiff'], 'title': '原告', 'valu...  侵權行為損害賠償
# 2012    [{'group': ['plaintiff'], 'title': '原告', 'valu...      損害賠償
# 2040    [{'group': ['plaintiff'], 'title': '原告', 'valu...      損害賠償
# 2041    [{'group': ['plaintiff'], 'title': '原告', 'valu...      損害賠償
# 2049    [{'group': ['plaintiff'], 'title': '原告', 'valu...      損害賠償
# 2169    [{'group': ['plaintiff'], 'title': '原告', 'valu...  侵權行為損害賠償
# 2170    [{'group': ['plaintiff'], 'title': '原告', 'valu...      損害賠償
# 2174    [{'group': ['plaintiff'], 'title': '原告', 'valu...      損害賠償
# 2175    [{'group': ['plaintiff', 'defendant'], 'title'...      損害賠償
# 2191    [{'group': ['plaintiff'], 'title': '原告', 'valu...  侵權行為損害賠償
# 2192    [{'group': ['plaintiff'], 'title': '原告', 'valu...      損害賠償
# 2193    [{'group': ['plaintiff'], 'title': '原告', 'valu...      損害賠償
# 2202    [{'group': ['plaintiff'], 'title': '原告', 'valu...  侵權行為損害賠償
# 2217    [{'group': ['plaintiff'], 'title': '原告', 'valu...      損害賠償
# 2228    [{'group': ['plaintiff'], 'title': '原告', 'valu...      損害賠償
# 2234    [{'group': ['plaintiff'], 'title': '原告', 'valu...      損害賠償
# 2250    [{'group': ['plaintiff'], 'title': '原告', 'valu...  侵權行為損害賠償
# 2263    [{'group': ['plaintiff'], 'title': '原告', 'valu...  侵權行為損害賠償
# 2264    [{'group': ['plaintiff'], 'title': '原告', 'valu...      損害賠償
# 2268    [{'group': ['plaintiff'], 'title': '原告', 'valu...      損害賠償
# 2272    [{'group': ['plaintiff'], 'title': '原告', 'valu...      損害賠償
# 2273    [{'group': ['plaintiff'], 'title': '原告', 'valu...      損害賠償
# 2275    [{'group': ['plaintiff'], 'title': '原告', 'valu...      損害賠償
# 2289    [{'group': ['plaintiff'], 'title': '原告', 'valu...      損害賠償
# 2294    [{'group': ['plaintiff'], 'title': '原告', 'valu...      損害賠償
# 2304    [{'group': ['plaintiff'], 'title': '原告', 'valu...      損害賠償
# 2306    [{'group': ['plaintiff'], 'title': '原告', 'valu...  侵權行為損害賠償
# 2311    [{'group': ['plaintiff'], 'title': '原告', 'valu...  侵權行為損害賠償
# 2315    [{'group': ['plaintiff'], 'title': '原告', 'valu...  侵權行為損害賠償
# 2323    [{'group': ['plaintiff'], 'title': '上訴人', 'val...      損害賠償
# ...                                                   ...       ...
# 333784  [{'group': ['plaintiff'], 'title': '原告', 'valu...  侵權行為損害賠償
# 333856  [{'group': ['plaintiff'], 'title': '上訴人', 'val...      損害賠償
# 334110  [{'group': ['plaintiff'], 'title': '原告', 'valu...      損害賠償
# 334116  [{'group': ['plaintiff'], 'title': '原告', 'valu...      損害賠償
# 334135  [{'group': ['plaintiff'], 'title': '原告', 'valu...      損害賠償
# 334272  [{'group': ['plaintiff'], 'title': '原告', 'valu...      損害賠償
# 334441  [{'group': ['plaintiff'], 'title': '原告', 'valu...      損害賠償
# 334605  [{'group': ['plaintiff'], 'title': '原告', 'valu...  侵權行為損害賠償
# 334822  [{'group': ['plaintiff'], 'title': '原告', 'valu...  侵權行為損害賠償
# 334849  [{'group': ['plaintiff'], 'title': '原告', 'valu...  侵權行為損害賠償
# 334911  [{'group': ['plaintiff', 'defendant'], 'title'...  侵權行為損害賠償
# 335077  [{'group': ['plaintiff'], 'title': '原告', 'valu...      損害賠償
# 335139  [{'group': ['plaintiff'], 'title': '原告', 'valu...      損害賠償
# 335420  [{'group': ['plaintiff'], 'title': '原告', 'valu...      損害賠償
# 335499  [{'group': ['plaintiff'], 'title': '原告', 'valu...  侵權行為損害賠償
# 335509  [{'group': ['plaintiff'], 'title': '原告', 'valu...  侵權行為損害賠償
# 335555  [{'group': ['plaintiff'], 'title': '原告', 'valu...  侵權行為損害賠償
# 335580  [{'group': ['plaintiff'], 'title': '原告', 'valu...  侵權行為損害賠償
# 335616  [{'group': ['plaintiff'], 'title': '原告', 'valu...  侵權行為損害賠償
# 335618  [{'group': ['plaintiff'], 'title': '原告', 'valu...  侵權行為損害賠償
# 335747  [{'group': ['plaintiff'], 'title': '原告', 'valu...  侵權行為損害賠償
# 336015  [{'group': ['plaintiff'], 'title': '原告', 'valu...  侵權行為損害賠償
# 336025  [{'group': ['plaintiff'], 'title': '原告', 'valu...  侵權行為損害賠償
# 336056  [{'group': ['plaintiff'], 'title': '原告', 'valu...  侵權行為損害賠償
# 336297  [{'group': ['plaintiff'], 'title': '原告', 'valu...      損害賠償
# 336303  [{'group': ['plaintiff'], 'title': '原告', 'valu...      損害賠償
# 336394  [{'group': ['plaintiff', 'defendant'], 'title'...      損害賠償
# 336425  [{'group': ['plaintiff'], 'title': '原告', 'valu...      損害賠償
# 336438  [{'group': ['plaintiff'], 'title': '原告', 'valu...      損害賠償
# 336475  [{'group': ['plaintiff'], 'title': '原告', 'valu...      損害賠償
#
#                                             relatedIssues sys type winOrloss  \
# 1970    [{'lawName': '民事訴訟法', 'issueRef': '78'}, {'law...  民事   判決      被吿勝訴
# 2012    [{'lawName': '刑事訴訟法', 'issueRef': '4871'}, {'l...  刑事   判決      被告敗訴
# 2040    [{'lawName': '中華民國刑法', 'issueRef': '354'}, {'l...  刑事   判決      被告敗訴
# 2041    [{'lawName': '中華民國刑法', 'issueRef': '354'}, {'l...  刑事   判決      被告敗訴
# 2049    [{'lawName': '中華民國刑法', 'issueRef': '354'}, {'l...  刑事   判決      被告敗訴
# 2169    [{'lawName': '民事訴訟法', 'issueRef': '79'}, {'law...  民事   判決      被告敗訴
# 2170    [{'lawName': '強制汽車責任保險法', 'issueRef': '30'}, {...  民事   判決      被告敗訴
# 2174    [{'lawName': '民事訴訟法', 'issueRef': '79'}, {'law...  民事   判決      被告敗訴
# 2175    [{'lawName': '刑事訴訟法', 'issueRef': '4871'}, {'l...  民事   判決      被告敗訴
# 2191    [{'lawName': '民事訴訟法', 'issueRef': '79'}, {'law...  民事   判決      被告敗訴
# 2192    [{'lawName': '中華民國刑法', 'issueRef': '2841'}, {'...  民事   判決      被告敗訴
# 2193    [{'lawName': '強制汽車責任保險法', 'issueRef': '30'}, {...  民事   判決      被告敗訴
# 2202    [{'lawName': '刑事訴訟法', 'issueRef': '5042'}, {'l...  民事   判決      被告敗訴
# 2217    [{'lawName': '勞動基準法', 'issueRef': '5411'}, {'l...  民事   判決      被告敗訴
# 2228    [{'lawName': '勞動基準法', 'issueRef': '111'}, {'la...  民事   判決      被告敗訴
# 2234    [{'lawName': '民事訴訟法', 'issueRef': '79'}, {'law...  民事   判決      被告敗訴
# 2250    [{'lawName': '民事訴訟法', 'issueRef': '256'}, {'la...  民事   判決      被告敗訴
# 2263    [{'lawName': '強制汽車責任保險法', 'issueRef': '32'}, {...  民事   判決      被告敗訴
# 2264    [{'lawName': '刑事訴訟法', 'issueRef': '5042'}, {'l...  民事   判決      被告敗訴
# 2268    [{'lawName': '中華民國刑法', 'issueRef': '2841'}, {'...  民事   判決      被告敗訴
# 2272    [{'lawName': '民事訴訟法', 'issueRef': '79'}, {'law...  民事   判決      被告敗訴
# 2273    [{'lawName': '民事訴訟法', 'issueRef': '79'}, {'law...  民事   判決      被告敗訴
# 2275    [{'lawName': '民事訴訟法', 'issueRef': '78'}, {'law...  民事   判決      被吿勝訴
# 2289    [{'lawName': '中華民國刑法', 'issueRef': '2841'}, {'...  民事   判決      被告敗訴
# 2294    [{'lawName': '民事訴訟法', 'issueRef': '79'}, {'law...  民事   判決      被告敗訴
# 2304    [{'lawName': '強制汽車責任保險法', 'issueRef': '251'}, ...  民事   判決      被告敗訴
# 2306    [{'lawName': '民事訴訟法', 'issueRef': '79'}, {'law...  民事   判決      被告敗訴
# 2311    [{'lawName': '強制汽車責任保險法', 'issueRef': '32'}, {...  民事   判決      被告敗訴
# 2315    [{'lawName': '強制汽車責任保險法', 'issueRef': '30'}, {...  民事   判決      被告敗訴
# 2323    [{'lawName': '刑事訴訟法', 'issueRef': '500'}, {'la...  民事   判決      被告敗訴
# ...                                                   ...  ..  ...       ...
# 333784  [{'lawName': '刑事訴訟法', 'issueRef': '5042'}, {'l...  民事   判決      被告敗訴
# 333856  [{'lawName': '商業會計處理準則', 'issueRef': '15'}, {'...  民事   判決      被吿勝訴
# 334110  [{'lawName': '勞動基準法', 'issueRef': '59'}, {'law...  民事   判決      被告敗訴
# 334116  [{'lawName': '民事訴訟法', 'issueRef': '38913'}, {'...  民事   判決      被告敗訴
# 334135  [{'lawName': '民事訴訟法', 'issueRef': '3922'}, {'l...  民事   判決      被告敗訴
# 334272  [{'lawName': '地方制度法', 'issueRef': '211'}, {'la...  民事   判決      被告敗訴
# 334441  [{'lawName': '中華民國刑法', 'issueRef': '185-311'},...  民事   判決      被告敗訴
# 334605  [{'lawName': '中華民國刑法', 'issueRef': '2781'}, {'...  民事   判決      被告敗訴
# 334822  [{'lawName': '民事訴訟法', 'issueRef': '79'}, {'law...  民事   判決      被告敗訴
# 334849  [{'lawName': '民事訴訟法', 'issueRef': '79'}, {'law...  民事   判決      被告敗訴
# 334911  [{'lawName': '民事訴訟法', 'issueRef': '25513'}, {'...  民事   判決      被告敗訴
# 335077  [{'lawName': '中華民國刑法', 'issueRef': '2841'}, {'...  民事   判決      被告敗訴
# 335139  [{'lawName': '國家賠償法', 'issueRef': '3'}, {'lawN...  民事   判決      被吿勝訴
# 335420  [{'lawName': '民事訴訟法', 'issueRef': '79'}, {'law...  民事   判決      被告敗訴
# 335499  [{'lawName': '民事訴訟法', 'issueRef': '79'}, {'law...  民事   判決      被告敗訴
# 335509  [{'lawName': '民事訴訟法', 'issueRef': '79'}, {'law...  民事   判決      被告敗訴
# 335555  [{'lawName': '民事訴訟法', 'issueRef': '79'}, {'law...  民事   判決      被告敗訴
# 335580  [{'lawName': '中華民國憲法', 'issueRef': '7'}, {'law...  民事   判決      被告敗訴
# 335616  [{'lawName': '強制汽車責任保險法', 'issueRef': '32'}, {...  民事   判決      被告敗訴
# 335618  [{'lawName': '民事訴訟法', 'issueRef': '151'}, {'la...  民事   判決      被告敗訴
# 335747  [{'lawName': '民事訴訟法', 'issueRef': '2801'}, {'l...  民事   判決      被告敗訴
# 336015  [{'lawName': '強制汽車責任保險給付標準', 'issueRef': '6'},...  民事   判決      被告敗訴
# 336025  [{'lawName': '保險法', 'issueRef': '53'}, {'lawNa...  民事   判決      被告敗訴
# 336056  [{'lawName': '民事訴訟法', 'issueRef': '79'}, {'law...  民事   判決      被告敗訴
#
# 334911  [(紙在, 0.3290302982449541), (職權, 0.329030298244...               6720.0
# 335077  [(骨折, 0.14984263966550002), (見店, 0.12198742349...             120000.0
# 335139  [(平交道, 0.18505832047832818), (僅請求, 0.148046656...                  0.0
# 335420  [(工作損失, 0.4044846147597744), (學生, 0.1797709398...             114693.6
# 335499  [(有理, 0.1845945667935185), (相抵, 0.155771838922...              24000.0
# 335509  [(062, 0.1149496875278846), (699, 0.1149496875...              24000.0
# 335555  [(日診斷, 0.35509210404653463), (鐵路, 0.3255010953...              87507.0
# 335580  [(CEDAW, 0.16795954342917355), (影卷, 0.16301955...            1600000.0
# 335616  [(千上, 0.4170267733569767), (160, 0.27801784890...            3114986.0
# 335618  [(地院, 0.4134213545671469), (沈秋星, 0.24116245683...               7098.0
# 335747  [(斟酌, 0.2395207073002857), (衛生署, 0.17078239289...               7315.0
# 336015  [(任險, 0.27673072923379627), (264, 0.2213845833...            2112000.0
# 336025  [(假山, 0.24085739164789563), (購物, 0.19502067704...             142173.5
# 336056  [(玉鐲, 0.2877515153870897), (爭玉鐲, 0.13079614335...              74324.6
# 336297  [(390, 0.17710766670962963), (同卷, 0.1475897222...              26575.5
# 336303  [(張西良, 0.34752231113081394), (急煞, 0.2182741271...                  0.0
# 336394  [(西園, 0.1763240044675516), (駕車行, 0.17632400446...               1600.0
# 336425  [(氣體, 0.21190134421683898), (吸入, 0.17852211654...              35000.0
# 336438  [(江長, 0.30828913331260743), (宜發, 0.23978043702...             200000.0
# 336475  [(IP, 0.29886918757250003), (李明旭, 0.2739634219...                700.0
#
# [17940 rows x 19 columns]

# %%
a=ltp.pdColFilter(x,"judgement","小孩")
p1=a[a['winOrloss']=='被告敗訴']
p2=p1[p1['jd_money']-p1['solatium_request']>=0]

win_probability=round(len(p1)/len(a)*100,2)
solatium_satisfy_probability=round(len(p2)/len(a)*100,2)
JD_Request=round((p1['jd_money'].mean())/(p1['solatium_request'].mean()),2)
print(
      'jd_num:',len(a),
      '\nwin_probability:',win_probability,
      '\nsolatium_satisfy_probability:',solatium_satisfy_probability,
      '\nJD/request:',JD_Request,
      '\njd_money_mean:',round(p1['jd_money'].mean(),2),
     '\nsolatium_request_mean:',round(p1['solatium_request'].mean(),2))
# Out:
# jd_num: 965
# win_probability: 89.53
# solatium_satisfy_probability: 33.99
# JD/request: 0.9
# jd_money_mean: 802851.0
# solatium_request_mean: 896770.77

# %%
D=ltp.pdTupleToDf(a["keyword"],"keyword","tfidf_value")
sector = D.groupby("keyword").sum()
d=D.sort_values(["tfidf_value"])
count = Counter(d['keyword']).most_common(500)
count=ltp.pdTupleToDf2(count,"keyword","count")
count['ratio']=round(count['count']/len(a)*100,2)
count
# Out:
#     keyword  count  ratio
# 0       看護費    437  45.28
# 1        骨折    211  21.87
# 2      工作損失    163  16.89
# 3      最高法院    134  13.89
# 4        頭部    120  12.44
# 5        不能    104  10.78
# 6        擦傷     93   9.64
# 7       性骨折     88   9.12
# 8        先行     83   8.60
# 9       霍夫曼     74   7.67
# 10       經濟     71   7.36
# 11       造成     66   6.84
# 12       嚴重     65   6.74
# 13     薪資損失     65   6.74
# 14   普通重型機車     62   6.42
# 15     重型機車     62   6.42
# 16       支付     60   6.22
# 17       是否     59   6.11
# 18       小孩     59   6.11
# 19       痛苦     59   6.11
# 20       請准     57   5.91
# 21     道路交通     56   5.80
# 22       撕裂     56   5.80
# 23       預供     56   5.80
# 24      腦震盪     55   5.70
# 25       能力     54   5.60
# 26       關節     53   5.49
# 27     所不爭執     53   5.49
# 28       無據     51   5.28
# 29       失能     50   5.18
# ..      ...    ...    ...
# 470      要旨      9   0.93
# 471      假牙      9   0.93
# 472      高職      9   0.93
# 473      癱瘓      9   0.93
# 474      途經      9   0.93
# 475     255      9   0.93
# 476      出現      9   0.93
# 477      車應      9   0.93
# 478      統一      9   0.93
# 479      分局      9   0.93
# 480      飲用      9   0.93
# 481      其行      9   0.93
# 482      國軍      9   0.93
# 483      幸福      9   0.93
# 484     128      9   0.93
# 485      相抵      9   0.93
# 486      顯著      9   0.93
# 487     122      9   0.93
# 488      出生      9   0.93
# 489      審判      9   0.93
# 490      受領      9   0.93
# 491     216      9   0.93
# 492      北屯      9   0.93
# 493      未劃      9   0.93
# 494      參仟      9   0.93
# 495      位置      9   0.93
# 496      手腕      9   0.93
# 497      臀部      9   0.93
# 498      所否      9   0.93
# 499      本庭      9   0.93
#
# [500 rows x 3 columns]

# %% [markdown]
# # 指標函式

# %%
x=pd.read_pickle("/Users/benbilly3/Desktop/Legaltech/MoreData/result.pickle")

def jdReport(dataframe,col_name,*args):
    for key in args:
        select=dataframe[col_name].values.tolist()
        a=[key in i for i in select]
        dataframe=dataframe[a]
        
    p1=dataframe[dataframe['winOrloss']=='被告敗訴']
    p2=p1[p1['jd_money']-p1['solatium_request']>=0]

    win_probability=round(len(p1)/len(dataframe)*100,2)
    solatium_satisfy_probability=round(len(p2)/len(dataframe)*100,2)
    JD_Request=round((dataframe['jd_money'].mean())/(dataframe['solatium_request'].mean()),2)
    data={
          '關鍵字出現案數':len(dataframe),
          '原告勝率':win_probability,
          '平均主文判決總賠償金(JD)':round(dataframe['jd_money'].mean(),2),
          '平均請求慰撫金(request)':round(dataframe['solatium_request'].mean(),2),
          'JD/request':JD_Request,
          '主文判決總賠償金大於慰撫金的比例':solatium_satisfy_probability,
          }
    name='&'.join([key for key in args])

    return pd.DataFrame(data,index=[name])

jdReport(x,"judgement",'扶養')
# Out:
#     關鍵字出現案數   原告勝率  平均主文判決總賠償金(JD)  平均請求慰撫金(request)  JD/request  \
# 扶養     2872  88.41      1244061.85        1831186.13        0.68
#
#     主文判決總賠償金大於慰撫金的比例
# 扶養             29.25

# %%
jdReport(x,"judgement",'植物人')
# Out:
#      關鍵字出現案數   原告勝率  平均主文判決總賠償金(JD)  平均請求慰撫金(request)  JD/request  \
# 植物人      436  85.55      4191437.08        2660129.53        1.58
#
#      主文判決總賠償金大於慰撫金的比例
# 植物人             46.79

# %% [markdown]
# # 測試重要關鍵字

# %%
keylist=pd.read_csv('/Users/benbilly3/Desktop/Legaltech/MoreData/plaintiff_win_300up_commonword.csv')
keylist=keylist['keyword'].values[:100]
keylist
# Out:
# array(['看護費', '霍夫曼', '骨折', '癱瘓', '植物人', '出血', '頭部', '嚴重', '終身', '自理',
#        '肢體', '最高法院', '平均', '重型機車', '能力', '所不爭執', '程度', '四肢', '協助', '下肢',
#        '失能', '監護', '實際', '年齡', '脊髓', '重傷', '不能', '勞動力', '道路交通', '用品',
#        '顱骨', '缺損', '日常生活', '全日', '腦膜', '負連帶', '輪椅', '單利', '算法', '判例',
#        '無力', '先行', '0000000000', '扶養費', '普通重型機車', '撫金', '功能', '受僱', '經濟',
#        '每日', '傷合', '重傷害', '支付', '交重', '偏癱', '生命表', '累計', '機能', '是否', '增加',
#        '安全措施', '時速', '濃度', '重大', '終結', '昏迷', '創傷', '義務', '語言', '187',
#        '顱內', '終生', '重度', '尚有', '伍拾', '尿布', '截肢', '審交重', '護理', '輔助',
#        '每月薪資', '工作損失', '判斷', '僱用', '192', '利者', '行駛至', '薪資損失', '交附民字',
#        '047', '日生', '扣繳', '基礎', '49', '開規定', '此為', '斟酌', '胸椎', '障害', '不爭'],
#       dtype=object)

# %%
def jdReport_list(dataframe,col_name,key_list):
    d=[]
    for k in keylist:
        data= jdReport(dataframe,col_name,k)
        d.append(data)
    return pd.concat(d)
df=jdReport_list(x,"judgement",keylist)

# %%
df.sort_values(['JD/request'],ascending=False)
# Out:
#         關鍵字出現案數   原告勝率  平均主文判決總賠償金(JD)  平均請求慰撫金(request)  JD/request  \
# 脊髓          482  86.93      3127058.38        1658723.00        1.89
# 癱瘓          584  88.87      4575158.02        2525697.45        1.81
# 尿布          442  91.40      3590743.79        2003283.84        1.79
# 偏癱          234  91.45      3996741.02        2275260.95        1.76
# 胸椎          373  90.08      2196183.00        1346335.64        1.63
# 終生          730  92.33      3220442.66        2019042.95        1.60
# 植物人         436  85.55      4191437.08        2660129.53        1.58
# 截肢          233  87.12      2560351.75        1680924.94        1.52
# 監護          680  85.59      3035084.49        1997916.00        1.52
# 語言          379  90.24      2967002.79        1985403.93        1.49
# 終身         1451  92.07      3083254.44        2084731.39        1.48
# 重傷害        1785  90.48      2841118.20        1934973.35        1.47
# 失能         1593  92.28      2087123.59        1428772.73        1.46
# 輪椅         1229  92.27      2074570.04        1416763.47        1.46
# 障害         1125  93.42      2146676.01        1525101.09        1.41
# 機能         1305  90.96      2155144.40        1538187.07        1.40
# 單利         1333  95.35      2703040.26        1976284.16        1.37
# 缺損          882  91.84      1874274.32        1401815.55        1.34
# 勞動力        1516  93.40      1747100.94        1304886.29        1.34
# 重度          772  86.79      2589473.12        1940062.01        1.33
# 重傷         2412  90.17      2454898.25        1876242.60        1.31
# 肢體         1698  89.81      1752553.00        1347433.39        1.30
# 四肢         1751  88.18      1675648.34        1312093.19        1.28
# 累計         2281  95.00      1384080.86        1097918.42        1.26
# 所不爭執               33.11
# 斟酌                 34.64
# 負連帶                32.84
# 判斷                 32.08
# 最高法院               34.03
# 撫金                 33.90
# 先行                 32.51
# 終結                 33.94
# 時速                 28.94
# 是否                 32.50
# 不爭                 32.42
# 義務                 32.66
# 道路交通               33.57
# 安全措施               32.22
# 交附民字               35.27
# 192                25.20
# 扶養費                20.36
#
# [100 rows x 6 columns]

# %%
df.to_csv('/Users/benbilly3/Desktop/Legaltech/ibus/百大高賠償金統計數據')

# %% [markdown]
# # 慰撫金請求金額直方圖
#
# 查詢各條件交集變化

# %%
x=pd.read_pickle("/Users/benbilly3/Desktop/Legaltech/MoreData/result.pickle")
a,b,c='客運','下肢','殘廢'
def jdReportHist(dataframe,col_name,*args):
    
    label_name=[]
    for key in args:
        select=dataframe[col_name].values.tolist()
        a=[key in i for i in select]
        dataframe=dataframe[a]
        dataframe=dataframe[dataframe['solatium_request']<10000000]
        x=dataframe['solatium_request'].values/10000
        
        plt.rcParams['font.family']=['Arial Unicode MS']
        plt.rcParams['font.size']=18
        plt.rcParams["figure.figsize"] = (20,12)
        plt.subplots_adjust(left=None, bottom=0.3, right=None, top=1.5,hspace = .27, wspace=.2)
        c = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])for i in range(1)]
        
        #處理label
        label_name.append(key)
        try:
            label_name2='&'.join(label_name)
        except:
            label_name2=label_name[0]
        
        plt.subplot(2,1,1,facecolor='lemonchiffon')
        ax= sns.distplot(x,bins=20,label=label_name2,kde=False)
        plt.xticks(range(0,1050,50))
        plt.ylabel('人數')
        plt.xlabel('請求金額(萬)')
        name='&'.join([key for key in args])
        plt.title(name+'--慰撫金請求金額直方圖(條件交集)',fontsize='xx-large')
        p=x.mean()
        plt.axvline(x=p,linewidth=4.5,color=c[0],label=label_name2+'平均金額')
        plt.legend()
        plt.grid(color='b', linestyle='--', linewidth=0.2)
        ax.legend()
        
        plt.subplot(2,1,2,facecolor='lemonchiffon')
        ax1= sns.kdeplot(x, shade=True,label=label_name2)
        plt.xticks(range(0,1050,50))
        plt.xlabel('請求金額(萬)')
        plt.title(name+'--慰撫金請求金額高斯分佈圖(條件交集)',fontsize='xx-large')
        plt.axvline(x=p,linewidth=4.5,color=c[0],label=label_name2+'平均金額')
        ax1.legend()

jdReportHist(x,"judgement",a,b,c)
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
# /anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
# /anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
# /anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "

# %%
x=pd.read_pickle("/Users/benbilly3/Desktop/Legaltech/MoreData/result.pickle")

def jdReportHistGaussian(dataframe,col_name,*args):
    for key in args:
        select=dataframe[col_name].values.tolist()
        a=[key in i for i in select]
        df2=dataframe[a]
        df2=df2[df2['solatium_request']<10000000]
        
        x=df2['solatium_request'].values/10000
        
        plt.rcParams['font.family']=['Arial Unicode MS']
        plt.rcParams['font.size']=18
        plt.rcParams["figure.figsize"] = (20,12)
        plt.subplots_adjust(left=None, bottom=0.3, right=None, top=1.5,hspace = .27, wspace=.2)
        c = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])for i in range(1)]
        plt.subplot(2,1,1,facecolor='snow')
        ax= sns.distplot(x,bins=20,label=key,kde=False)
        p=x.mean()
        plt.axvline(x=p,linewidth=4.5,color=c[0],label=key+'平均金額')
        plt.xticks(range(0,1050,50))
        plt.ylabel('人數')
        plt.xlabel('請求金額(萬)')
        name='&'.join([key for key in args])
        plt.title(name+'慰撫金請求金額直方圖',fontsize='xx-large')
        plt.grid(color='b', linestyle='--', linewidth=0.2)
        ax.legend()
        
        plt.subplot(2,1,2,facecolor='snow')
        ax1= sns.kdeplot(x, shade=True,label=key)
        plt.axvline(x=p,linewidth=4.5,color=c[0],label=key+'平均金額')
        plt.xticks(range(0,1100,50))
        plt.xlabel('請求金額(萬)')
        plt.title(name+'慰撫金請求金額高斯分佈圖',fontsize='xx-large')
        ax1.legend()

jdReportHistGaussian(x,"judgement",a,b,c)
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
# /anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
# /anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
# /anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "

# %%
def jdReportHistRealPredict(dataframe,col_name,*args):
    
    title_name='&'.join([key for key in args])
    for keyword in args:
        select=dataframe[col_name].values.tolist()
        a=[keyword in i for i in select]
        dataframe=dataframe[a]
    
    for i in ['solatium_request','jd_solatium_predict']:
        dataframe=dataframe[dataframe[i]<10000000]
        x=dataframe[i].values/10000

        plt.rcParams['font.family']=['Arial Unicode MS']
        plt.rcParams['font.size']=18
        plt.rcParams["figure.figsize"] = (20,12)
        plt.subplots_adjust(left=None, bottom=0.3, right=None, top=1.5,hspace = .27, wspace=.2)
        c = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])for i in range(1)]
        c2 = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])for i in range(1)]
        
        plt.subplot(2,1,1,facecolor='lemonchiffon')
        if i=='solatium_request':
            name='請求金額'
        else:
            name='實判預估金額'
        ax= sns.distplot(x,bins=20,label=name,kde=False)
        plt.xticks(range(0,1050,50))
        plt.ylabel('案數')
        plt.xlabel('金額(萬)')
        plt.title(title_name+'--慰撫金請求金額V.S實判預估金額',fontsize='xx-large')
        p=x.mean()
        plt.axvline(x=p,linewidth=4.5,color=c[0],label=name+'平均金額')
        plt.legend()
        plt.grid(color='b', linestyle='--', linewidth=0.2)
        ax.legend()
        
        plt.subplot(2,1,2,facecolor='lemonchiffon')
        ax1= sns.kdeplot(x, shade=True,label=name)
        plt.xticks(range(0,1050,50))
        plt.xlabel('金額(萬)')
        plt.title(title_name+'--慰撫金請求金額V.S實判預估金額',fontsize='xx-large')
        plt.axvline(x=p,linewidth=4.5,color=c2[0],label=name+'平均金額')
        plt.grid(color='b', linestyle='--', linewidth=0.2)
        ax1.legend()

jdReportHistRealPredict(x,"judgement",a,b,c)
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
# /anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "

# %% [markdown]
# # 法院案件統計圖

# %%
df=pd.read_pickle("/Users/benbilly3/Desktop/Legaltech/MoreData/result.pickle")

def jdReportScatterRealPredict(df,col_name,*args):
    df=df.reset_index()
    df=df[df['solatium_request']<10000000]
    df=df[df['jd_money']<50000000]
    df['solatium_request']=df['solatium_request']/10000
    df['jd_solatium_predict']=df['jd_solatium_predict']/10000
    df['jd_money']=df['jd_money']/10000
    for keyword in args:
        select=df[col_name].values.tolist()
        a=[keyword in i for i in select]
        df=df[a]
    plt.rcParams['font.family']=['Arial Unicode MS']
    plt.rcParams['font.size']=18
    plt.rcParams["figure.figsize"] = (28,25)
    plt.subplots_adjust(left=None, bottom=0.3, right=None, top=1,hspace = .2, wspace=.24)
    
#     #請求金額與主文判決總金額散點圖
#     plt.subplot(2,1,1,facecolor='snow')
    name='&'.join([key for key in args])
#     cmap = sns.cubehelix_palette(dark=.3, light=.8, as_cmap=True)
#     ax = sns.scatterplot(x="jd_solatium_predict", y="jd_money",
#                          hue="court", size="jd_solatium_predict",sizes=(100, 500),
#                          palette="Set3",data=df)
#     plt.title(name+'--各地法院慰撫金請求金額V.S主文總判金額',fontsize='xx-large')
    
    plt.subplot(1,1,1,facecolor='snow')
    df2=df.groupby('court').count()
    df2=df2.iloc[:,0:1]
    df2=df2.sort_values('index',ascending=False)
    df2=df2.reset_index()
    ax2 = sns.barplot(x="index", y="court", data=df2)
    plt.title(name+'--各地法院案件數',fontsize='xx-large')
    
    #標籤
    for x, y, tex in zip(df2['index'], df2.index, df2['index']):
        t = plt.text(x, y,int(tex), horizontalalignment='right', 
                     verticalalignment='center', fontdict={'color':'black', 'size':20})
    df.to_csv('/Users/benbilly3/Desktop/Legaltech/ibus/'+name+'--各地法院案件數.csv')    

jdReportScatterRealPredict(x,"judgement",a,b,c)

# %%
df=pd.read_pickle("/Users/benbilly3/Desktop/Legaltech/MoreData/result.pickle")

def jdReportBarRealPredict(df,col_name,*args):
    df=df.reset_index()
    df=df[df['solatium_request']<10000000]
    df=df[df['jd_money']<50000000]
    df['solatium_request']=df['solatium_request']/10000
    df['jd_solatium_predict']=df['jd_solatium_predict']/10000
    df['jd_money']=df['jd_money']/10000
    for keyword in args:
        select=df[col_name].values.tolist()
        a=[keyword in i for i in select]
        df=df[a]
    plt.rcParams['font.family']=['Arial Unicode MS']
    plt.rcParams['font.size']=24
    plt.rcParams["figure.figsize"] = (24,16)
    plt.subplots_adjust(left=None, bottom=0.3, right=None, top=1,hspace = .27, wspace=.6)

    plt.subplot(1,2,1)
    df2=df.groupby('court').mean()
    df2=df2.sort_values('solatium_request',ascending=False)
    df2=df2.iloc[:,2:3]
    df2=df2.reset_index()
    name='&'.join([key for key in args])
    cmap=sns.diverging_palette(220, 20, len(df2))
    ax2 = sns.barplot(x="solatium_request", y="court",palette=cmap, data=df2)
    plt.title(name+'--各地法院慰撫金請求金額平均數',fontsize='medium')
    for x, y, tex in zip(df2['solatium_request'], df2.index, df2['solatium_request']):
        t = plt.text(x, y,int(tex), horizontalalignment='right', 
                     verticalalignment='center', fontdict={'color':'black', 'size':20})
    
    
    plt.subplot(1,2,2,facecolor='snow')
    df2=df.groupby('court').mean()
    df2=df2.sort_values('jd_solatium_predict',ascending=False)
    df2=df2.iloc[:,3:4]
    df2=df2.reset_index()
    cmap=sns.cubehelix_palette(len(df2),dark=.3, light=.8)

    ax2 = sns.barplot(x="jd_solatium_predict", y="court",palette=cmap, data=df2)
    plt.title(name+'--各地法院慰撫金推估實判金額平均數',fontsize='medium')
    for x, y, tex in zip(df2['jd_solatium_predict'], df2.index, df2['jd_solatium_predict']):
        t = plt.text(x, y,int(tex), horizontalalignment='right', 
                     verticalalignment='center', fontdict={'color':'black', 'size':20})
#     return df2
        
    
jdReportBarRealPredict(x,"judgement",a,b,c)
